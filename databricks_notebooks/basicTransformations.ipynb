# %%
customer_df=spark.read.option('header','true')\
    .option('inferschema','true')\
        .csv('/Volumes/workspace/default/test')
customer_df.show()

# %%
newdf=customer_df.select('customer_name','city')
newdf.show()

# %%
customer_df.select('city').show()

# %%
customer_df.limit(10).show()

# %%
customer_df.offset(3).show()

# %%
#customer_df.filter(customer_df.city=='Chennai').show()
from pyspark.sql.functions import col
write_df=customer_df.filter(col('city')=='Chennai')

# %%
from pyspark.sql.functions import col
otherdata=customer_df.filter(col('city')=='Chennai')

# %%
write_df.write.option('header','true').mode('append').csv('/Volumes/workspace/default/test/tranformed_data')

# %%
write_df.write.mode('append').parquet('/Volumes/workspace/default/test/parquetData')

# %%
parquet_df=spark.read.option('header','true')\
    .option('inferschema','true')\
        .parquet('/Volumes/workspace/default/test/parquetData')
customer_df.show()

# %%
write_df.write.format('delta').mode('overwrite').save('/Volumes/workspace/default/test/deltadata')

# %%
#customer_df.withColumn('country',expression)
from pyspark.sql.functions import lit
test_df=customer_df.withColumn('country',lit(2))
test_df.printSchema()

# %%
otherdata.write.format('delta').mode('overwrite').save('/Volumes/workspace/default/test/deltadata')

# %%
delta_df=spark.read.format('delta').load('/Volumes/workspace/default/test/deltadata')
delta_df.show()

# %%
delta_df=spark.read.format('delta').option('versionAsOf',1).load('/Volumes/workspace/default/test/deltadata')
delta_df.show()

# %%
from delta.tables import DeltaTable
delta_hist=DeltaTable.forPath(spark,'/Volumes/workspace/default/test/deltadata')
display(delta_hist.history())

# %% [markdown]
# Select Case
#         When condition1 Then "valid"
#         When condition2 Then 'invalid'
#         END

# %%
#I want to classify email of customer is valid or not
from pyspark.sql.functions import when,col
newdf=customer_df.withColumn('email_status',when(col('email').contains('@'),'Valid').otherwise('invalid'))
newdf.show()

# %%
newdf.printSchema()

# %%
cleaned_df=customer_df.drop('phone','customer_id')

# %%
cleaned_df.show()

# %%
renamed_columns_df1 = customer_df.withColumnRenamed('customer_name','name').withColumnRenamed('phone','phone_number')

# %%
renamed_columns_df1.show()

# %%
display(customer_df)

# %%
display(customer_df.distinct())

# %%
display(customer_df.dropDuplicates(["customer_id",'customer_name']))

# %%
#orderBy
from pyspark.sql.functions import desc
customer_df.orderBy(desc('city')).show()

# %% [markdown]
# Select city,count(customer_name)
# From customer_df
# Group By city

# %%
customer_df.groupBy('city').count().show()

# %%
customer_df.createOrReplaceTempView('customers')

# %%
result_df=spark.sql("""Select city,count(customer_name)
From customers
Group By city""")

result_df.show()

# %%
result_df=spark.sql("""Select *
From customers
Where city=='Chennai'""")

result_df.show()
